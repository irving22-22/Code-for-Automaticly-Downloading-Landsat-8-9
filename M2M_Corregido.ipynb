# %%
import json
from getpass import getpass
import requests
import sys
import time
import cgi
import os
import pandas as pd
import geopandas as gpd
import warnings
warnings.filterwarnings("ignore")
apiKey = "4oCpGCCrIET5H@Cd"

# %%
# Send http request
def sendRequest(url, data, apiKey = None, exitIfNoResponse = True):
    """
    Send a request to an M2M endpoint and returns the parsed JSON response.

    Parameters:
    endpoint_url (str): The URL of the M2M endpoint
    payload (dict): The payload to be sent with the request

    Returns:
    dict: Parsed JSON response
    """
      
    json_data = json.dumps(data)
    
    if apiKey == None:
        response = requests.post(url, json_data)
    else:
        headers = {'X-Auth-Token': apiKey}              
        response = requests.post(url, json_data, headers = headers)  
    
    try:
      httpStatusCode = response.status_code 
      if response == None:
          print("No output from service")
          if exitIfNoResponse: sys.exit()
          else: return False
      output = json.loads(response.text)
      if output['errorCode'] != None:
          print(output['errorCode'], "- ", output['errorMessage'])
          if exitIfNoResponse: sys.exit()
          else: return False
      if  httpStatusCode == 404:
          print("404 Not Found")
          if exitIfNoResponse: sys.exit()
          else: return False
      elif httpStatusCode == 401: 
          print("401 Unauthorized")
          if exitIfNoResponse: sys.exit()
          else: return False
      elif httpStatusCode == 400:
          print("Error Code", httpStatusCode)
          if exitIfNoResponse: sys.exit()
          else: return False
    except Exception as e: 
          response.close()
          print(e)
          if exitIfNoResponse: sys.exit()
          else: return False
    response.close()
    
    return output['data']

# %%
def downloadfiles(downloadIds):
    downloadIds.append(download['downloadId'])
    print("    DOWNLOADING: " + download['url'])
    downloadResponse = requests.get(download['url'], stream=True)

    # parse the filename from the Content-Disposition header
    content_disposition = cgi.parse_header(downloadResponse.headers['Content-Disposition'])[1]
    filename = os.path.basename(content_disposition['filename'])
    filepath = os.path.join(data_dir, filename)

    # write the file to the destination directory
    with open(filepath, 'wb') as f:
        for data in downloadResponse.iter_content(chunk_size=8192):
            f.write(data)
    #print(f"    DOWNLOADED {filename} ({i+1}/{len(downloadIds)})")

# %%
data_dir = 'data'
utils_dir = 'utils'
dirs = [ data_dir, utils_dir]

for d in dirs:
        if not os.path.exists(d): 
            try: 
                os.makedirs(d)
                print(f"Directory '{d}' created successfully.") 
            except OSError as e: 
                print(f"Error creating directory '{d}': {e}") 
        else: 
            print(f"Directory '{d}' already exists.")
# Out:
# Directory 'data' already exists.
# Directory 'utils' already exists.

# %%
username = "Irving2209"
token = "bzkI06wtA!tXNxkD7FubEVhFS2O80BSxZToZTBr6QtBg5ojEzTxes7c5FXDI7LXK"

# %%
print("Logging in...\n")
    
serviceUrl = "https://m2m.cr.usgs.gov/api/api/json/stable/"
login_payload = {'username' : username, 'token' : token}
    
apiKey = sendRequest(serviceUrl + "login-token", login_payload)
    
print("API Key: " + apiKey + "\n")
# Out:
# Logging in...
#
# API Key: eyJjaWQiOjI2OTI0MTc4LCJzIjoiMTc1OTQzMDk5MSIsInIiOjk0NywicCI6WyJ1c2VyIiwiZG93bmxvYWQiLCJvcmRlciJdfQ==

# %% [markdown]
# ## **1. Create an Area of Interest (AOI) GeoJSON Text File** <a id="createaoi"></a>

# %% [markdown]
# Polygon coordinates are arranged in the sequence NE, NW, SW, SE, NE, representing all four corners, with an extra NE point to conclude and close the polygon.

# %%
from geojson import Polygon, Feature, FeatureCollection, dump

bounding_box = [[-57.7448764485,-25.4967482196],  # Lower left (min longitude, min latitude)
                [-57.809500565,-25.2208058563],  # Lower right (max longitude, min latitude)
                [-57.4572636009,-25.1520434564],  # Upper right (max longitude, max latitude)
                [-57.3713346464,-25.4486640975],  # Upper left (min longitude, max latitude)
                [-57.7448764485,-25.4967482196]] # Closing the polygon (back to lower left)

polygon = Polygon([bounding_box])

features = []
features.append(Feature(geometry=polygon, properties={"region": "Panama Centro"}))

feature_collection = FeatureCollection(features)

with open('./utils/panama_centro.geojson', 'w') as f:
    dump(feature_collection, f)

# %%
aoi_geodf = gpd.read_file('./utils/panama_centro.geojson')

# %% [markdown]
# - ### View the Coordinate Reference System (CRS)
#
# > The CRS used is the World Geodetic System 1984 with units in degrees.

# %%
aoi_geodf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
aoi_geodf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03a5b076237238b66cfcf91832a2f91c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03a5b076237238b66cfcf91832a2f91c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03a5b076237238b66cfcf91832a2f91c = L.map(
#                 &quot;map_03a5b076237238b66cfcf91832a2f91c&quot;,
#                 {
#                     center: [-25.3243955, -57.590418],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_03a5b076237238b66cfcf91832a2f91c);
#
#
#
#
#
#             var tile_layer_8527a56e15d1885b13bd980ec5c59168 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_03a5b076237238b66cfcf91832a2f91c);
#
#
#             map_03a5b076237238b66cfcf91832a2f91c.fitBounds(
#                 [[-25.496748, -57.809501], [-25.152043, -57.371335]],
#                 {}
#             );
#
#
#         function geo_json_67becdaa7ca9057ecd57b4375ab63e9a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_67becdaa7ca9057ecd57b4375ab63e9a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_67becdaa7ca9057ecd57b4375ab63e9a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_67becdaa7ca9057ecd57b4375ab63e9a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_67becdaa7ca9057ecd57b4375ab63e9a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_67becdaa7ca9057ecd57b4375ab63e9a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_67becdaa7ca9057ecd57b4375ab63e9a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_67becdaa7ca9057ecd57b4375ab63e9a = L.geoJson(null, {
#                 onEachFeature: geo_json_67becdaa7ca9057ecd57b4375ab63e9a_onEachFeature,
#
#                 style: geo_json_67becdaa7ca9057ecd57b4375ab63e9a_styler,
#                 pointToLayer: geo_json_67becdaa7ca9057ecd57b4375ab63e9a_pointToLayer
#         });
#
#         function geo_json_67becdaa7ca9057ecd57b4375ab63e9a_add (data) {
#             geo_json_67becdaa7ca9057ecd57b4375ab63e9a
#                 .addData(data)
#                 .addTo(map_03a5b076237238b66cfcf91832a2f91c);
#         }
#             geo_json_67becdaa7ca9057ecd57b4375ab63e9a_add({&quot;bbox&quot;: [-57.809501, -25.496748, -57.371335, -25.152043], &quot;features&quot;: [{&quot;bbox&quot;: [-57.809501, -25.496748, -57.371335, -25.152043], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-57.744876, -25.496748], [-57.809501, -25.220806], [-57.457264, -25.152043], [-57.371335, -25.448664], [-57.744876, -25.496748]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;region&quot;: &quot;Panama Centro&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_67becdaa7ca9057ecd57b4375ab63e9a.bindTooltip(
#     function(layer){
#     let di

# %% [markdown]
# - ### Plot AOI using Folium
#
# > The ***folium*** module is used for creating interactive web maps.

# %% [markdown]
# ## **2. Submit a [*dataset-search*](https://m2m.cr.usgs.gov/api/docs/reference/#dataset-search)**<a id="dataset-search"></a>
#
# The [***dataset-search***](https://m2m.cr.usgs.gov/api/docs/reference/#dataset-search) is used to find available collections of datasets. Users can pass the API without search parameters to view all the available datasets; however, in this case, we use the ***'datasetName'*** input parameter to limit the search to find datasets with ***'Landsat 8-9'*** since Landsat-8 and Landsat-9 datasets are grouped.
#
# - ### Setup search  parameters into a ***payload*** used for sending requests:
#
# > Adding a [***temporal-filter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#temporalFilter) will return data collections available within a set period of time. The ***'start'*** and ***'end'*** dates in ISO format (**yyyy-mm-dd**) for the time period of interest.

# %%
temporalFilter = {'start' : '2025-09-05', 'end' : '2025-10-01'}

# %% [markdown]
# - ### Include ***'Landsat 8-9'*** as ***'datasetName'***:
#
# > Note that ***'Landsat 8-9'***  is not a ***'datasetName'*** but can be used to query for specifically Landsat-8 or Landsat-9 data.

# %%
datasearch_payload = {'datasetName': 'Landsat 8-9',
                     'temporalFilter' : temporalFilter}

# %%
datasearch_result = sendRequest(serviceUrl + "dataset-search", datasearch_payload, apiKey)

# %% [markdown]
# <div class="alert alert-info">
#     <h4>To find the <b><i>datasetName</i></b> for other collections of Landsat data:</h4>
#     <ol>
#         <li>
#             Run a request with the <a href="https://m2m.cr.usgs.gov/api/docs/reference/#dataset-search" target="_blank">
#                 <b><i>dataset-search</i></b>
#             </a> request and extract the <b><i>'datasetAlias'</i></b> field. No input parameters are necessary!
#         </li>
#         <li>
#             Run the <b><i>dataset-search</i></b> endpoint using the
#             <a href="https://m2m.cr.usgs.gov/api/test/json/" target="_blank">
#                 <b><i>Machine-to-Machine (M2M) Test Page</i></b>.
#             </a>
#         </li>
#     </ol>
# </div>

# %% [markdown]
# - ### Visualize results using *pandas*:

# %%
pd.json_normalize(datasearch_result)
# Out:
#                                         abstractText acquisitionStart  \
# 0  The USGS Earth Resources Observation and Scien...       2013-04-11
# 1  The USGS Earth Resources Observation and Scien...       2013-04-11
#
#   acquisitionEnd  catalogs              collectionName  \
# 0           None  [EE, GV]  Landsat 8-9 OLI/TIRS C2 L1
# 1           None      [EE]  Landsat 8-9 OLI/TIRS C2 L2
#
#                                   collectionLongName         datasetId  \
# 0  Landsat 8-9 Operational Land Imager and Therma...  5e81f14f59432a27
# 1  Landsat 8-9 Operational Land Imager and Therma...  5e83d14f2fc39685
#
#        datasetAlias           datasetCategoryName dataOwner  ... legacyId  \
# 0  landsat_ot_c2_l1  Landsat Collection 2 Level-1      LSAA  ...     9825
# 1  landsat_ot_c2_l2  Landsat Collection 2 Level-2      LSAA  ...     9885
#
#   sceneCount                                   temporalCoverage  \
# 0    4298995  ["2013-03-08 00:00:00-06","2025-09-29 00:00:00...
# 1    3714007  ["2013-03-18 00:00:00-05","2025-09-27 00:00:00...
#
#   supportCloudCover  supportDeletionSearch  allowInKmz spatialBounds.north  \
# 0              True                   True        True           84.441827
# 1              True                   True        True           84.441827
#
#    spatialBounds.east  spatialBounds.south  spatialBounds.west
# 0          197.576528           -84.571377         -180.009967
# 1          194.444152           -84.517917         -180.009967
#
# [2 rows x 24 columns]

# %% [markdown]
# ## **3. Send a [*dataset-filters*](https://m2m.cr.usgs.gov/api/docs/reference/#dataset-filters) Request** <a id="dataset-filters"></a>
# The [***dataset-filters***](https://m2m.cr.usgs.gov/api/docs/reference/#dataset-filters) request returns the [***metadataFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#metadataFilter) parameters for the specified dataset. These values can be used as additional criteria when submitting search queries for specific scenes. The ***'datasetName'*** input parameter is necessary.
#
# > Note that the Landsat-9 Collection 2 Level 2 datasets has the ***dataAlias:*** ***'landsat_ot_c2_l2'***

# %%
datasetName = datasearch_result[0]['datasetAlias']

# %%
datafilter_payload = {'datasetName': datasetName}
datafilter_result = sendRequest(serviceUrl + "dataset-filters", datafilter_payload, apiKey)

# %% [markdown]
# > Below we plot the results from the [***dataset-filters***](https://m2m.cr.usgs.gov/api/docs/reference/#dataset-filters) query. The **`fieldLabel`** provides insights into the queryable fields available for this specific Landsat data collection. While the **`fieldConfig.type`** that lists types `Text`, `Range` and `Select` guides users on the appropriate [***metadataFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#metadataFilter) type to apply.
#
# > **Example:**
# > - If type is `Text`, then use a `'like'` or `'='` operand in a `'value'` metadataFilter
# > - If type is `Select`, then check the `valueList` for valid values to use in a `'value'` metadataFilter (use the key on the left, not the label on the right)
# > - If type is `Range`, then use a `'between'` metadataFilter and provide `'firstValue'` and `'secondValue'`

# %%
pd.json_normalize(datafilter_result)
# Out:
#                   id  legacyFieldId  \
# 0   5e81f14fe3c40983        27678.0
# 1   5e81f14f8faf8048        27679.0
# 2   5e81f14f8d2a7c24        27680.0
# 3   61af93b8fad2acf5            NaN
# 4   5e81f14f85d499dc        27685.0
# 5   5e81f14f61bda7c4        27686.0
# 6   5e81f150e42bc489        27690.0
# 7   5e81f150c2f58f31        27790.0
# 8   5e81f14fcf660794        27684.0
# 9   5e81f14fff5055a3        27683.0
# 10  5e81f15023925fb4        27688.0
# 11  5e81f14f830b749b        27689.0
# 12  5e81f14fbba2e223        27691.0
# 13   6266f9f8dc71ab1            NaN
#
#                                        dictionaryLink  \
# 0   https://www.usgs.gov/centers/eros/science/land...
# 1   https://www.usgs.gov/centers/eros/science/land...
# 2   https://www.usgs.gov/centers/eros/science/land...
# 3   https://www.usgs.gov/centers/eros/science/land...
# 4   https://www.usgs.gov/centers/eros/science/land...
# 5   https://www.usgs.gov/centers/eros/science/land...
# 6   https://www.usgs.gov/centers/eros/science/land...
# 7   https://www.usgs.gov/centers/eros/science/land...
# 8   https://www.usgs.gov/centers/eros/science/land...
# 9   https://www.usgs.gov/centers/eros/science/land...
# 10  https://www.usgs.gov/centers/eros/science/land...
# 11  https://www.usgs.gov/centers/eros/science/land...
# 12  https://www.usgs.gov/centers/eros/science/land...
# 13  https://www.usgs.gov/centers/eros/science/land...
#
#                                 fieldLabel  \
# 0            Landsat Product Identifier L1
# 1                                 WRS Path
# 2                                  WRS Row
# 3                                Satellite
# 4                        Sensor Identifier
# 5                      Day/Night Indicator
# 6                          Nadir/Off Nadir
# 7                       Sun Elevation L0RA
# 8                             Data Type L1
# 9                      Collection Category
# 10  Date Product Generated L1 (YYYY/MM/DD)
# 11           Geometric RMSE Model (meters)
# 12                Landsat Scene Identifier
# 13                           Image Quality
#
#                              searchSql fieldConfig.type  \
# 0         LANDSAT_PRODUCT_ID_L1 like ?             Text
# 1                   WRS_PATH between ?            Range
# 2                    WRS_ROW between ?            Range
# 3                         satellite =?           Select
# 4                        SENSOR_ID = ?           Select
# 5                        DAY_NIGHT = ?           Select
# 6                   NADIR_OFFNADIR = ?           Select
# 7         SUN_ELEVATION_L0RA between ?            Range
# 8           RIGHT(DATA_TYPE_L1, 4) = ?           Select
# 9              COLLECTION_CATEGORY = ?           Select
# 10  trunc(DATE_L1_GENERATED) between ?            Range
# 11      GEOMETRIC_RMSE_MODEL between ?            Range
# 12                    ENTITY_ID like ?             Text
# 13                   Image_Quality = ?           Select
#
#                                   fieldConfig.filters  \
# 0   [{'type': 'Application\Filter\Like', 'options'...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4          [{'type': 'StringToUpper', 'options': []}]
# 5          [{'type': 'StringToUpper', 'options': []}]
# 6          [{'type': 'StringToUpper', 'options': []}]
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12  [{'type': 'StringToUpper', 'options': []}, {'t...
# 13                                                 []
#
#    fieldConfig.options.size             fieldConfig.validators  \
# 0                        45                                 []
# 1                       NaN                                 []
# 2                       NaN                                 []
# 3                       NaN                                 []
# 4                         4                                 []
# 5                         3                                 []
# 6                         3                                 []
# 7                       NaN                                 []
# 8                         4                                 []
# 9                         4                                 []
# 10                      NaN  [{'type': 'Date', 'options': {}}]
# 11                      NaN                                 []
# 12                       25                                 []
# 13                      NaN                                 []
#
#    fieldConfig.numElements  ... valueList.OFFNADIR valueList.L1TP  \
# 0                        5  ...                NaN            NaN
# 1                        1  ...                NaN            NaN
# 2                        1  ...                NaN            NaN
# 3                      NaN  ...                NaN            NaN
# 4                        1  ...                NaN            NaN
# 5                        1  ...                NaN            NaN
# 6                        1  ...          Off Nadir            NaN
# 7                        1  ...                NaN            NaN
# 8                        1  ...                NaN      Level 1TP
# 9                        1  ...                NaN            NaN
# 10                     NaN  ...                NaN            NaN
# 11                       1  ...                NaN            NaN
# 12                       5  ...                NaN            NaN
# 13                     NaN  ...                NaN            NaN
#
#    valueList.L1GT valueList.L1GS valueList.T1 valueList.T2 valueList.RT  \
# 0             NaN            NaN          NaN          NaN          NaN
# 1             NaN            NaN          NaN          NaN          NaN
# 2             NaN            NaN          NaN          NaN          NaN
# 3             NaN            NaN          NaN          NaN          NaN
# 4             NaN            NaN          NaN          NaN          NaN
# 5             NaN            NaN          NaN          NaN          NaN
# 6             NaN            NaN          NaN          NaN          NaN
# 7             NaN            NaN          NaN          NaN          NaN
# 8       Level 1GT      Level 1GS          NaN          NaN          NaN
# 9             NaN            NaN       Tier 1       Tier 2    Real-Time
# 10            NaN            NaN          NaN          NaN          NaN
# 11            NaN            NaN          NaN          NaN          NaN
# 12            NaN            NaN          NaN          NaN          NaN
# 13            NaN            NaN          NaN          NaN          NaN
#
#    fieldConfig.options.size  valueList.0                     valueList.-1
# 0                        NaN         NaN                              NaN
# 1                        NaN         NaN                              NaN
# 2                        NaN         NaN                              NaN
# 3                        NaN         NaN                              NaN
# 4                        NaN         NaN                              NaN
# 5                        NaN         NaN                              NaN
# 6                        NaN         NaN                              NaN
# 7                        NaN         NaN                              NaN
# 8                        NaN         NaN                              NaN
# 9                        NaN         NaN                              NaN
# 10                       NaN         NaN                              NaN
# 11                       NaN         NaN                              NaN
# 12                       NaN         NaN                              NaN
# 13                        30   Worst = 0  Image Quality Not Assessed = -1
#
# [14 rows x 32 columns]

# %% [markdown]
# ## **4. Setup *scene-filters* and to submit a *scene-search*:**<a id="scene-search"></a>

# %% [markdown]
# - ### Setup [***Scene-filters***](https://m2m.cr.usgs.gov/api/docs/datatypes/#sceneFilter):
#
# > The [***spatialFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#spatialFilter), [***acquisitionFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#acquisitionFilter), [**metadataFilter**](https://m2m.cr.usgs.gov/api/docs/datatypes/#metadataFilter) and [***cloudCoverFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#cloudCoverFilter) are [***scene-filters***](https://m2m.cr.usgs.gov/api/docs/datatypes/#sceneFilter) used below to identify the scenes matching the filter criteria using [**scene-search**](https://m2m.cr.usgs.gov/api/docs/reference/#scene-search).
# >
# > #### [***spatialFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#spatialFilter)
# >
# > There are two spatial ***filterType's***:
# >
# > 1. [***geojson***](https://m2m.cr.usgs.gov/api/docs/datatypes/#spatialFilterGeoJson) which needs a ***['geoJson'](https://m2m.cr.usgs.gov/api/docs/datatypes/#geoJson)*** field name labeled with a geometric ***'type'*** e.g. ***'Polygon'*** and includes the coordinate array of the polygon:
# >
# > ~~~~
# >        spatialFilter = {'filterType' : 'geojson',
# >                 'geoJson' : {'type': 'Polygon',\
# >                              'coordinates': [[[-75.446, 36.3793],\
# >                                                                  [-76.9196, 36.3793],\
# >                                                                  [-76.9196, 35.5713],
# >                                                                  [-75.446, 35.5713],\
# >                                                                  [-75.446, 36.3793]]]}}
# >
# > ~~~~
# >
# > 2. [***mbr***](https://m2m.cr.usgs.gov/api/docs/datatypes/#spatialFilterMbr) (Minimum Bounding Rectangle) where the user should include the ***'lowerLeft'*** (southwest point) and ***'upperRight'*** (northeast point) of the rectangle as ***{'latitude': ######, 'longitude' : ######}*** coordinates:
# >
# > ```
# >        spatialFilter =  {'filterType' : 'mbr',
# >                      'lowerLeft' : {'latitude' : 35.5713,\
# >                                     'longitude' : -76.9196},
# >                     'upperRight' : { 'latitude' : 36.3793,\
# >                                     'longitude' : -75.446}}
# > ```

# %%
spatialFilter =  {'filterType' : 'mbr',
                    'lowerLeft' : {'latitude' : float(aoi_geodf.bounds.miny[0]),\
                                   'longitude' : float(aoi_geodf.bounds.minx[0])},
                   'upperRight' : { 'latitude' : float(aoi_geodf.bounds.maxy[0]),\
                                   'longitude' : float(aoi_geodf.bounds.maxx[0])}}

# spatialFilter = {'filterType' : 'geojson',
#                  'geoJson' : {'type': 'Polygon',\ 
#                               'coordinates': [[[-57.7448764485,-25.4967482196],\
#                                                                   [-57.809500565,-25.2208058563],\
#                                                                   [-57.4572636009,-25.1520434564],
#                                                                   [-57.3713346464,-25.4486640975],\
#                                                                   [-57.7448764485,-25.4967482196]]]}}

# %% [markdown]
# > #### [***acquisitionFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#acquisitionFilter)
# > The [***acquisitionFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#acquisitionFilter) is the ***'start'*** and ***'end'*** dates in ISO format for the time period of interest. In our case it will be the same as the ***temporalFilter*** used above. It is also in ISO format **yyyy-mm-dd**.

# %%
temporalFilter = {'start' : '2025-09-05', 'end' : '2025-10-01'}

# %% [markdown]
# > #### [***metadataFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#metadataFilter)
# > The [***metadataFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#metadataFilter) is used to narrow down the scene search to find specific scenes e.g. in our case searching only for Landsat-9 images. A ***'filterId'*** (from the [***dataset-filters***](https://m2m.cr.usgs.gov/api/docs/reference/#dataset-filters) result), ***'filterType'*** and ***'value'*** (9 for Landsat-9) are necessary when searching for datasets from a specific satellite.

# %%
filterId = datafilter_result[3]['id'] #because the id for the satellite metadata filter
#filterId = datasearch_result[1]['datasetId']#gives error: Expecting ',' delimiter: line 1 column 163 (char 162)
metadataFilter = {'filterType': 'value',
                    'filterId': filterId,
                    'value' : '8'} # Filtro del satelite 8 o 9

# %% [markdown]
# > #### [***cloudCoverFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#cloudCoverFilter)
# > To filter scenes by cloud cover, you can use the [***cloudCoverFilter***](https://m2m.cr.usgs.gov/api/docs/datatypes/#cloudCoverFilter) and specify a ***'min'*** and ***'max'*** percentage (%) value..

# %%
cloudCoverFilter = {'min' : 0, 'max' : 15}

# %% [markdown]
# - ### Combine all parameters into a *payload* used for sending requests:

# %%
search_payload = {
    'datasetName' : datasetName,
    'sceneFilter' : {
        'metadataFilter' : metadataFilter,
        'spatialFilter' : spatialFilter,
        'acquisitionFilter' : temporalFilter,
        'cloudCoverFilter' : cloudCoverFilter
    }
}

# %%
search_payload
# Out:
# {'datasetName': 'landsat_ot_c2_l1',
#  'sceneFilter': {'metadataFilter': {'filterType': 'value',
#    'filterId': '61af93b8fad2acf5',
#    'value': '8'},
#   'spatialFilter': {'filterType': 'mbr',
#    'lowerLeft': {'latitude': -25.496748, 'longitude': -57.809501},
#    'upperRight': {'latitude': -25.152043, 'longitude': -57.371335}},
#   'acquisitionFilter': {'start': '2025-03-20', 'end': '2025-05-01'},
#   'cloudCoverFilter': {'min': 0, 'max': 20}}}

# %% [markdown]
# - ### Submit a [***scene-search***](https://m2m.cr.usgs.gov/api/docs/reference/#scene-search)
#
#
# > The [***scene-search***](https://m2m.cr.usgs.gov/api/docs/reference/#scene-search) is used for searching for scenes within a dataset collection, a ***'datasetName'*** parameter is required.

# %%
scenes = sendRequest(serviceUrl + "scene-search", search_payload, apiKey)

# %%
results = pd.json_normalize(scenes['results'])
results_gdf = gpd.GeoDataFrame(results)
results_gdf.head()
# Out:
#                                               browse  cloudCover  \
# 0  [{'id': '5e81f7d39594374', 'browseRotationEnab...           7
#
#                 entityId                                 displayId orderingId  \
# 0  LC82260772025262LGN00  LC08_L1TP_226077_20250919_20250929_02_T1       None
#
#                                             metadata hasCustomizedMetadata  \
# 0  [{'id': '5e81f1503645de13', 'fieldName': 'ID',...                  None
#
#               publishDate  options.bulk  options.download  ...  \
# 0  2025-09-19 11:30:19-05          True              True  ...
#
#    options.secondary  selected.bulk  selected.compare  selected.order  \
# 0              False          False             False           False
#
#    spatialBounds.type                          spatialBounds.coordinates  \
# 0             Polygon  [[[-58.82677, -25.60513], [-58.82677, -23.5027...
#
#   spatialCoverage.type                        spatialCoverage.coordinates  \
# 0              Polygon  [[[-58.82677, -25.22535], [-56.9616, -25.60513...
#
#   temporalCoverage.endDate temporalCoverage.startDate
# 0      2025-09-19 00:00:00        2025-09-19 00:00:00
#
# [1 rows x 21 columns]

# %% [markdown]
# # Visualización de los footprints de las imàgenes a descargar.

# %%
results_gdf["geometry"] = results_gdf['spatialBounds.coordinates'].apply(lambda x : Polygon(x))
results_gdf = results_gdf.set_crs(crs="EPSG:4326")

# %%
results_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47e9b5fa10cb7c51598dd23fe3cd5898 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47e9b5fa10cb7c51598dd23fe3cd5898&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47e9b5fa10cb7c51598dd23fe3cd5898 = L.map(
#                 &quot;map_47e9b5fa10cb7c51598dd23fe3cd5898&quot;,
#                 {
#                     center: [-24.553955000000002, -57.690885],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_47e9b5fa10cb7c51598dd23fe3cd5898);
#
#
#
#
#
#             var tile_layer_abba541103feaed9e39367380969addd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_47e9b5fa10cb7c51598dd23fe3cd5898);
#
#
#             map_47e9b5fa10cb7c51598dd23fe3cd5898.fitBounds(
#                 [[-25.60513, -58.82677], [-23.50278, -56.555]],
#                 {}
#             );
#
#
#         function geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_33e148a6e62dbfcd9f3de73f9cfa907a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_33e148a6e62dbfcd9f3de73f9cfa907a = L.geoJson(null, {
#                 onEachFeature: geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_onEachFeature,
#
#                 style: geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_styler,
#                 pointToLayer: geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_pointToLayer
#         });
#
#         function geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_add (data) {
#             geo_json_33e148a6e62dbfcd9f3de73f9cfa907a
#                 .addData(data)
#                 .addTo(map_47e9b5fa10cb7c51598dd23fe3cd5898);
#         }
#             geo_json_33e148a6e62dbfcd9f3de73f9cfa907a_add({&quot;bbox&quot;: [-58.82677, -25.60513, -56.555, -23.50278], &quot;features&quot;: [{&quot;bbox&quot;: [-58.82677, -25.60513, -56.555, -23.50278], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-58.82677, -25.60513], [-58.82677, -23.50278], [-56.555, -23.50278], [-56.555, -25.60513], [-58.82677, -25.60513]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;browse&quot;: &quot;[{\u0027id\u0027: \u00275e81f7d39594374\u0027, \u0027browseRotationEnabled\u0027: None, \u0027browseName\u0027: \u0027Reflective Color - Bands 6, 5, 4\u0027, \u0027browsePath\u0027: \u0027https://landsatlook.usgs.gov/gen-browse?size=rrb\u0026t

# %% [markdown]
# - ### Create a list of ***SceneIds***
#
# > The ***entityIds*** are [Landsat Scene Identifiers](https://www.usgs.gov/centers/eros/science/landsat-collection-2-data-dictionary#landsat_scene_id) that remain consistent for all levels and products available for each scene. Below we group all entityIds into a variable called *`sceneIds`*.

# %%
sceneIds = []
for result in scenes['results']:
    # Add this scene to the list I would like to download
    sceneIds.append(result['entityId'])
    
sceneIds
# Out:
# ['LC82260772025262LGN00']

# %% [markdown]
# ## **5. Find the [***download-options***](https://m2m.cr.usgs.gov/api/docs/reference/#download-options) for the scenes**<a id="download-options"></a>
#
# The [***download-options***](https://m2m.cr.usgs.gov/api/docs/reference/#download-options) request is used to discover downloadable products for each dataset. If a download is marked as not available, an order must be placed to generate that product. A ***'datasetName'*** parameter is required.

# %%
download_payload = {'datasetName' : datasetName, 
                    'entityIds' : sceneIds}

downloadOptions = sendRequest(serviceUrl + "download-options", download_payload, apiKey)

# %%
pd.json_normalize(downloadOptions)
# Out:
#                  id                                       downloadName  \
# 0  632211e26883b1f7
# 1  73ceb05468b7e8c2                            C2L1 Tile Product Files
# 2  6447cc2e2a09aab6                            C2L1 Tile Product Files
# 3  5e81f14f92acf9ef
# 4  5e9eb01274d7924f  Full Resolution Browse (Reflective Color) GeoTIFF
# 5  5e9eb12795d8231b
# 6  5e9eb2249228fe8f                                               None
# 7  5f6184a83f05bbf9     Full Resolution Browse (Reflective Color) JPEG
# 8  5f618512b2d7b4be                                               None
# 9  5f618552dc40c587                                               None
#
#                                   displayId               entityId  \
# 0  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 1  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 2  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 3  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 4  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 5  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 6  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 7  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 8  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
# 9  LC08_L1TP_226077_20250919_20250929_02_T1  LC82260772025262LGN00
#
#           datasetId  available    filesize  \
# 0  5e81f14f59432a27       True  1200673331
# 1  5e81f14f59432a27       True           0
# 2  5e81f14f59432a27       True           0
# 3  5e81f14f59432a27      False  1200673331
# 4  5e81f14f59432a27       True    14680064
# 5  5e81f14f59432a27       True    14680064
# 6  5e81f14f59432a27       True    14680064
# 7  5e81f14f59432a27       True     6291456
# 8  5e81f14f59432a27       True     6291456
# 9  5e81f14f59432a27       True     6291456
#
#                                       productName productCode  bulkAvailable  \
# 0     Landsat Collection 2 Level-1 Product Bundle        D805           True
# 1          Landsat Collection 2 Level-1 Band File        D687           True
# 2          Landsat Collection 2 Level-1 Band File        D689           True
# 3     Landsat Collection 2 Level-1 Product Bundle        D690          False
# 4  Full-Resolution Browse (Natural Color) GeoTIFF        D734           True
# 5        Full-Resolution Browse (Thermal) GeoTIFF        D735           True
# 6        Full-Resolution Browse (Quality) GeoTIFF        D736           True
# 7     Full-Resolution Browse (Natural Color) JPEG        D731           True
# 8           Full-Resolution Browse (Thermal) JPEG        D732           True
# 9           Full-Resolution Browse (Quality) JPEG        D733           True
#
#   downloadSystem                                 secondaryDownloads  \
# 0         dds_ms  [{'id': '5e8207607217ef3e', 'downloadName': ''...
# 1         folder  [{'id': '5e8207607217ef3e', 'downloadName': ''...
# 2         folder  [{'id': '5e8207607217ef3e', 'downloadName': ''...
# 3         ls_zip  [{'id': '5e8207607217ef3e', 'downloadName': ''...
# 4         ls_frb                                                 []
# 5         ls_frb                                                 []
# 6         ls_frb                                                 []
# 7         ls_frb                                                 []
# 8         ls_frb                                                 []
# 9         ls_frb                                                 []
#
#   fileGroups                           checksum
# 0       None                                NaN
# 1       None  [{'id': 'sha512', 'value': None}]
# 2       None  [{'id': 'sha512', 'value': None}]
# 3       None                                NaN
# 4       None                                NaN
# 5       None                                NaN
# 6       None                                NaN
# 7       None                                NaN
# 8       None                                NaN
# 9       None                                NaN

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h4> <b>NOTE:</b> The scene list cannot exceed 50,000 items. </h4>
# </div>

# %% [markdown]
# - ### Create a list of available products using results from [***download-options***](https://m2m.cr.usgs.gov/api/docs/reference/#download-options)
#
# > Make sure the product is available for this scene and ignore `'folders'` since they are tile files:

# %%
availableproducts = []
for product in downloadOptions:
        # Make sure the product is available for this scene
        if product['available'] == True and product['downloadSystem'] != 'folder':
                availableproducts.append({'entityId' : product['entityId'],
                                   'productId' : product['id']})

# %%
availableproducts
# Out:
# [{'entityId': 'LC82260772025262LGN00', 'productId': '632211e26883b1f7'},
#  {'entityId': 'LC82260772025262LGN00', 'productId': '5e9eb01274d7924f'},
#  {'entityId': 'LC82260772025262LGN00', 'productId': '5e9eb12795d8231b'},
#  {'entityId': 'LC82260772025262LGN00', 'productId': '5e9eb2249228fe8f'},
#  {'entityId': 'LC82260772025262LGN00', 'productId': '5f6184a83f05bbf9'},
#  {'entityId': 'LC82260772025262LGN00', 'productId': '5f618512b2d7b4be'},
#  {'entityId': 'LC82260772025262LGN00', 'productId': '5f618552dc40c587'}]

# %% [markdown]
# ## **6. Submit a [*download-request*](https://m2m.cr.usgs.gov/api/docs/reference/#download-request)**<a id="download-request"></a>
#
# The [**download-request**](https://m2m.cr.usgs.gov/api/docs/reference/#download-request) is used to request download urls and adds them to a queue.

# %%
requestedDownloadsCount = len(availableproducts)

# set a label for the download request
label = "download-sample"
download_req_payload = {'downloads' : availableproducts,
                                 'label' : label}

requestResults = sendRequest(serviceUrl + "download-request", download_req_payload, apiKey)
requestResults
# Out:
# {'availableDownloads': [{'downloadId': 790721113,
#    'eulaCode': None,
#    'entityId': 'LC80120542025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-bundle?landsat_product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721114,
#    'eulaCode': None,
#    'entityId': 'LC80120542025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frb&type=refl&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721115,
#    'eulaCode': None,
#    'entityId': 'LC80120542025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frb&type=tir&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721116,
#    'eulaCode': None,
#    'entityId': 'LC80120542025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frb&type=qb&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721117,
#    'eulaCode': None,
#    'entityId': 'LC80120542025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frbj&type=refl&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721118,
#    'eulaCode': None,
#    'entityId': 'LC80120542025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frbj&type=tir&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721119,
#    'eulaCode': None,
#    'entityId': 'LC80120542025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frbj&type=qb&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721120,
#    'eulaCode': None,
#    'entityId': 'LC80120552025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-bundle?landsat_product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721121,
#    'eulaCode': None,
#    'entityId': 'LC80120552025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frb&type=refl&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721122,
#    'eulaCode': None,
#    'entityId': 'LC80120552025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frb&type=tir&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721123,
#    'eulaCode': None,
#    'entityId': 'LC80120552025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frb&type=qb&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721124,
#    'eulaCode': None,
#    'entityId': 'LC80120552025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frbj&type=refl&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721125,
#    'eulaCode': None,
#    'entityId': 'LC80120552025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frbj&type=tir&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature='},
#   {'downloadId': 790721126,
#    'eulaCode': None,
#    'entityId': 'LC80120552025091LGN00',
#    'url': 'https://landsatlook.usgs.gov/gen-browse?size=frbj&type=qb&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature='}],
#  'duplicateProducts': [],
#  'preparingDownloads': [],
#  'failed': [],
#  'newRecords': {'790721113': 'download-sample',
#   '790721114': 'download-sample',
#   '790721115': 'download-sample',
#   '790721116': 'download-sample',
#   '790721117': 'download-sample',
#   '790721118': 'download-sample',
#   '790721119': 'download-sample',
#   '790721120': 'download-sample',
#   '790721121': 'download-sample',
#   '790721122': 'download-sample',
#   '790721123': 'download-sample',
#   '790721124': 'download-sample',
#   '790721125': 'download-sample',
#   '790721126': 'download-sample'},
#  'remainingLimits': [{'limitType': 'user',
#    'username': 'Irving2209',
#    'recentDownloadCount': 14986,
#    'pendingDownloadCount': 20000,
#    'unattemptedDownloadCount': 19997},
#   {'limitType': 'ip',
#    'ipAddress': '190.140.131.142',
#    'recentDownloadCount': 14986,
#    'pendingDownloadCount': 20000,
#    'unattemptedDownloadCount': 20000}],
#  'numInvalidScenes': 0}

# %% [markdown]
# ## **7. Submit a [*download-retrieve*](https://m2m.cr.usgs.gov/api/docs/reference/#download-retrieve)**<a id="download-retrieve"></a>
#
# Here we call the [***download-retrieve***](https://m2m.cr.usgs.gov/api/docs/reference/#download-retrieve) method to get products that are not immediately available for download, these are listed under the **`'preparingDownloads'`** results after sending a ***download-request***. The download links that are immediately available are retrieved from the **`'availableDownloads'`** list.

# %%
 if requestResults['preparingDownloads'] != None and len(requestResults['preparingDownloads']) > 0:
    download_retrieve_payload = {'label' : label}
    
    print("Requesting for additional available download urls...")
    moreDownloadUrls = sendRequest(serviceUrl + "download-retrieve", download_retrieve_payload, apiKey)

    downloadIds = []  



    print("\nDownloading from available downloads:")    
    for download in moreDownloadUrls['available']:
        if str(download['downloadId']) in requestResults['newRecords'] or str(download['downloadId']) in requestResults['duplicateProducts']:
            downloadfiles(downloadIds)




    print("\nDownloading from requested downloads:")        
    for download in moreDownloadUrls['requested']:
        if str(download['downloadId']) in requestResults['newRecords'] or str(download['downloadId']) in requestResults['duplicateProducts']:
            downloadfiles(downloadIds)               



    # Didn't get all of the reuested downloads, call the download-retrieve method again probably after 30 seconds
    while len(downloadIds) < (requestedDownloadsCount - len(requestResults['failed'])): 
        preparingDownloads = requestedDownloadsCount - len(downloadIds) - len(requestResults['failed'])
        print("    ", preparingDownloads, " downloads are not available. Waiting for 30 seconds...")
        time.sleep(30)
        print("    Trying to retrieve data after waiting for 30 seconds...")
        moreDownloadUrls = sendRequest(serviceUrl + "download-retrieve", download_retrieve_payload, apiKey)
        for download in moreDownloadUrls['available']:                            
            if download['downloadId'] not in downloadIds and (str(download['downloadId']) in requestResults['newRecords'] or str(download['downloadId']) in requestResults['duplicateProducts']):
                downloadfiles(downloadIds)


else:
    print("\nAll downloads are available to download. Retrieving...\n")# Get all available downloads
    i = 0
    for download in requestResults['availableDownloads']:
        
        print("DOWNLOADING: " + download['url'])
        
        downloadResponse = requests.get(download['url'], stream=True)

        # parse the filename from the Content-Disposition header
        content_disposition = cgi.parse_header(downloadResponse.headers['Content-Disposition'])[1]
        filename = os.path.basename(content_disposition['filename'])
        filepath = os.path.join(data_dir, filename)

        # write the file to the destination directory
        with open(filepath, 'wb') as f:
            for data in downloadResponse.iter_content(chunk_size=8192):
                f.write(data)
        i+=1
        print(f"DOWNLOADED {filename} ({i}/{len(requestResults['availableDownloads'])})\n")
# Out:
# All downloads are available to download. Retrieving...
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-bundle?landsat_product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012054_20250401_20250411_02_T1.tar (1/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frb&type=refl&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012054_20250401_20250411_02_T1_refl.tif (2/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frb&type=tir&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012054_20250401_20250411_02_T1_tir.tif (3/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frb&type=qb&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012054_20250401_20250411_02_T1_qb.tif (4/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frbj&type=refl&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012054_20250401_20250411_02_T1.jpg (5/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frbj&type=tir&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012054_20250401_20250411_02_T1_TIR.jpg (6/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frbj&type=qb&product_id=LC08_L1TP_012054_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012054_20250401_20250411_02_T1_QB.jpg (7/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-bundle?landsat_product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012055_20250401_20250411_02_T1.tar (8/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frb&type=refl&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012055_20250401_20250411_02_T1_refl.tif (9/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frb&type=tir&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012055_20250401_20250411_02_T1_tir.tif (10/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frb&type=qb&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012055_20250401_20250411_02_T1_qb.tif (11/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frbj&type=refl&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012055_20250401_20250411_02_T1.jpg (12/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frbj&type=tir&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012055_20250401_20250411_02_T1_TIR.jpg (13/14)
#
# DOWNLOADING: https://landsatlook.usgs.gov/gen-browse?size=frbj&type=qb&product_id=LC08_L1TP_012055_20250401_20250411_02_T1&requestSignature=
# DOWNLOADED LC08_L1TP_012055_20250401_20250411_02_T1_QB.jpg (14/14)

# %% [markdown]
# ## **8. [*Logout*](https://m2m.cr.usgs.gov/api/docs/reference/#logout) of M2M Endpoint**<a id="logout-api"></a>
#
# Logout so the API Key cannot be used anymore.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <h4> <b>NOTE:</b> The Machine-to-Machine API key expires after 2 hours of inactivity. </h4>
# </div>

# %%
endpoint = "logout"  
if sendRequest(serviceUrl + endpoint, None, apiKey) == None:        
    print("\n\nLogged Out\n")
else:
    print("\n\nLogout Failed\n")
# Out:
# Logged Out

# %% [markdown]
# ## **9. List Downloads**

# %%
os.listdir(data_dir)
# Out:
# ['LC09_L2SP_012054_20230319_20230321_02_T1.tar',
#  'LC09_L2SP_012055_20230303_20230308_02_T1.tar',
#  'LC09_L2SP_012055_20230319_20230321_02_T1.tar',
#  'LC09_L2SP_013054_20230310_20230312_02_T1.tar']
